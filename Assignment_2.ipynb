# %%
### Q1
There are 2 values of Boolean data type- True / False
 
### Q2
Boolean Operators- AND , OR and NOT

### Q3

TRUE and TRUE --> TRUE
TRUE and FALSE --> FALSE
FALSE and TRUE --> FALSE
FALSE and FALSE --> FALSE

TRUE or TRUE --> TRUE
TRUE or FALSE --> TRUE
FALSE or TRUE --> TRUE
FALSE or FALSE --> FALSE

### Q4
FALSE
FALSE
TRUE
FALSE
FALSE
TRUE

### Q5

==
!=
<>
>
<
>=
<=

### Q6

Assignment Operator (=) is used to when we need to assign a value to some variable but the equal to (==) is a comparison operator which is used when we need to compare 2 values.
Eg.
Using assignment operator (=)           --->   a=5 ( this assigns 'a' a value of 5)
Using equal to comapraison operator(==) --->    5==6 ( this gives false as 5 is not equal to 6)


### Q7

spam=0
# block-1
if spam==10:
    print("eggs")
#block-2
if spam>5:
    print('bacon')
#block-3
else:
    print('ham')
    print('spam')
    print('spam')
    
    
### Q-8

spam=0
if spam==1:
    print("Hello")
elif(spam==2):
    print('Howdy')
else:
    print("Greeting")
    
### Q-9 

Go to Kernel and click on "interuppt" or 'restart' kernel

### Q-10
if in a loop if we us 'break' , we come out of the loop but if using  'continue' then it comes out of the current itertion and goes to the next itertion

### Q-11

There is no difference between results of all three .It is just different ways of writing where the notations are as below

range(starting point(included) , ending point(excluded), jump)

### Q-12

#for loop
for i in range(1,11):
    print(i)

#while loop
i=1    
while(i<11):
    print (i)
    i+=1

    
### Q-13

bacon()
# Out:
#   File "<ipython-input-1-768e94247328>", line 2
#     There are 2 values of
#           ^
# SyntaxError: invalid syntax
