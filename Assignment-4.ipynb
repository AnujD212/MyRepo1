# %%
### Q-1
[]- This sign is for a list and if it happens to be empty then it means that we are defining an empty list as below
a=[]


### Q-2

spam=[2,4,6,8,10]
spam[2]="hello"
spam

### Q-3
spam=['a','b','c','d']

ans- 'd'         #('3'*2 ==> 33/11 ==>3)


### Q-4

'd'

### Q-5

['a','b']


### Q-6

bacon=[3.14,'cat',11,'cat',True]

ans-  1 ( as it gives index of 1st occureence)

### Q-7 

bacon=[3.14,'cat',11,'cat',True,99]


###Q-8

bacon=[3.14,11,'cat',True]


###  Q-9

concatenation -  '+'
replication-   '*'



### Q-10

Append- adds the elemnent at the end of the list

Insert- Takes 2 arguments(element, position)- Adds the element at the specified postiion


### Q-11
.remove
.pop
.del


### Q-12

In both of them we can use slicing, indexing,len() and can be iterated,concatenated,replicated

### Q-13 

List are mutable represented by []  but tuples are immutable represented by ().

### Q-14

a=(42,)

### Q-15



#tuple form of list
list1=[1,2,3]
tuple(list1)

#list form of a tuple
a=(1,2,3)
list(a)




### Q-16

They contain the references to the list value


### Q-17 

copy.copy()---- also called Shallow Copy
copy.deepcopy() ---- also called Deep Copy

Copy() and deepcopy() are similar for a normal list( 1-d) 
but differ in nested lists as different memory locations 
are created in deep copy case but not in shallow copy
